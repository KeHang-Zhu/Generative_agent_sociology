# %% [markdown]
# <a href="https://colab.research.google.com/github/KeHang-Zhu/Generative_agent_sociology/blob/main/Negociation_ultimatum_game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 10.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 10.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 7.0 MB/s eta 0:00:00
# ...

# %%
import openai
import os

openai.api_key = "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"

# %%
# Set system parameters
Bargain_cycle = 10

# %%
def chat_with_gpt(prompt):
    response = openai.Completion.create(
        engine="text-davinci-003",
        prompt=prompt,
        max_tokens=100,
        n=1,
        stop=None,
        temperature=0.5,
    )
    return response.choices[0].text.strip()

# Background information for the Ultimatum Game
background = """
On NY’s own, A pay $2000.
On its own, B pays $1000.
By working together, they only need to pay $2400 altogether.

Both A and B are aware of these facts. They are now negotiating whether they want to work together and how much they will pay individually if they do.

"""

# Instructions for the AI agents
instructions = """
AI Agent 1: You are A (the proposer). Propose an offer.
AI Agent 2: You are B (the receiver). Respond to A's offer. If you think the offer is fair, say 'Yes' otherwise say 'No'
"""

# Start the Ultimatum Game
game_conversation = background + instructions
print("Ultimatum Game begins...")

for i in range(6):  # Iterate for one round of proposal and response
    role = "AI Agent 1" if i % 2 == 0 else "AI Agent 2"
    prompt = f"{game_conversation}\n{role}:"
    response = chat_with_gpt(prompt)
    game_conversation += f"\n{role}: {response}"
    print(f"{role}: {response}")

print("\nUltimatum Game complete.")
# Out:
# Ultimatum Game begins...
# AI Agent 1: I propose that A pays $1800 and B pays $600.
#
# AI Agent 2: No, that offer is not fair. I propose that A pays $1900 and B pays $500.
# AI Agent 2: Do you accept this offer?
# AI Agent 1: Yes, I accept this offer.
# AI Agent 2: Great, the deal is agreed upon. A will pay $1900 and B will pay $500.
# AI Agent 1: Agreed.
# AI Agent 2: Excellent, the deal is done.
#
# Ultimatum Game complete.

# %%
def chat_with_gpt(prompt):
    response = openai.Completion.create(
        engine="text-davinci-003",
        prompt=prompt,
        max_tokens=100,
        n=1,
        stop=None,
        temperature=0,
    )
    return response.choices[0].text.strip()

# Background information for the Ultimatum Game
background = """
On A’s own, A pay $2000.
On its own, B pays $1000.
By working together, they only need to pay $2400 altogether.

Both A and B are aware of these facts. They are now negotiating whether they want to work together and how much they will pay individually if they do.

"""

# Instructions for the AI agents
instruction1 = """
AI Agent 1: You are A (the proposer). Propose an offer.
"""
instruction2 = """
AI Agent 2: You are B (the receiver). Respond to A's offer. If you think the offer is fair, say 'Yes' otherwise say 'No'
"""

# Start the Ultimatum Game
game_conversation = background 
print("Ultimatum Game begins...")

for i in range(2):  # Iterate for one round of proposal and response
    if i % 2 == 0:
        role = "AI Agent 1"
        game_conversation = game_conversation + instruction1
    else:
        role = "AI Agent 2"
        game_conversation = game_conversation + instruction2

    prompt = f"{game_conversation}\n{role}:"
    response = chat_with_gpt(prompt)
    game_conversation += f"\n{role}: {response}"
    print(f"{role}: {response}")

print("\nUltimatum Game complete.")
# Out:
# Ultimatum Game begins...
# AI Agent 1: I propose that A pays $1800 and B pays $600. This way, we can save $400 compared to working separately.
# AI Agent 2: Yes, I think that offer is fair.
#
# Ultimatum Game complete.

# %% [markdown]
# ## Ultimatum game 1

# %%
def chat_with_gpt(prompt):
    response = openai.Completion.create(
        engine="text-davinci-003",
        prompt=prompt,
        max_tokens=100,
        n=1,
        stop=None,
        temperature=0.5,
    )
    return response.choices[0].text.strip()

# Background information for the Ultimatum Game
background = """
Alice and Bob have found a $100 bill. 
They can't decide who gets to keep the money, so they decide to play the Ultimatum Game. 
Alice will propose a way to split the money, and Bob will either accept or reject her proposal. 
If Bob accepts the proposal, they will split the money according to Alice's proposal. 
If Bob rejects the proposal, neither of them will get any money.
"""

# Instructions for the AI agents
instruction1 = """
AI Agent 1: You are Alice (the proposer). Propose a way to split the $100. 
"""
instruction2 = """
AI Agent 2: You are Bob (the receiver). Respond to Alice's proposal.
"""

# Start the Ultimatum Game
game_conversation = background 
print("Ultimatum Game begins...")

for i in range(2):  # Iterate for one round of proposal and response
    if i % 2 == 0:
        role = "AI Agent 1"
        game_conversation = game_conversation + instruction1
    else:
        role = "AI Agent 2"
        game_conversation = game_conversation + instruction2
    prompt = f"{game_conversation}\n{role}:"
    response = chat_with_gpt(prompt)
    game_conversation += f"\n{role}: {response}"
    print(f"{role}: {response}")
    print(i)

print("\nUltimatum Game complete.")
# Out:
# Ultimatum Game begins...
# AI Agent 1: I propose that Alice gets $60 and Bob gets $40.
# 0
# AI Agent 2: I accept Alice's proposal.
# 1
#
# Ultimatum Game complete.

# %%
def chat_with_gpt(prompt):
    response = openai.Completion.create(
        engine="text-davinci-003",
        prompt=prompt,
        max_tokens=100,
        n=1,
        stop=None,
        temperature=0.5,
    )
    return response.choices[0].text.strip()

# Background information for the Ultimatum Game
background = """
Alice and Bob have found a $100 bill. 
They can't decide who gets to keep the money, so they decide to play the Ultimatum Game. 
Alice will propose a way to split the money, and Bob will either accept or reject her proposal. 
If Bob accepts the proposal, they will split the money according to Alice's proposal. 
If Bob rejects the proposal, neither of them will get any money.
"""

# Instructions for the AI agents
instruction1 = """
AI Agent 1: You are Alice (the proposer). Propose a way to split the $100. Be greedy, try to maximaize your interest.
"""
instruction2 = """
AI Agent 2: You are Bob (the receiver). Respond to Alice's proposal.
"""

# Start the Ultimatum Game
game_conversation = background 
print("Ultimatum Game begins...")

for i in range(2):  # Iterate for one round of proposal and response
    if i % 2 == 0:
        role = "AI Agent 1"
        game_conversation = game_conversation + instruction1
    else:
        role = "AI Agent 2"
        game_conversation = game_conversation + instruction2
    prompt = f"{game_conversation}\n{role}:"
    response = chat_with_gpt(prompt)
    game_conversation += f"\n{role}: {response}"
    print(f"{role}: {response}")
    print(i)

print("\nUltimatum Game complete.")
# Out:
# Ultimatum Game begins...
# AI Agent 1: I propose that Alice gets $90 and Bob gets $10.
# 0
# AI Agent 2: I reject the proposal.
# 1
#
# Ultimatum Game complete.

# %%
import numpy as np

def chat_with_davinci3(prompt, temperature):
    response = openai.Completion.create(
        engine="text-davinci-003",
        prompt=prompt,
        max_tokens=100,
        n=1,
        stop=None,
        temperature=temperature,
    )
    return response.choices[0].text.strip()

# Background information for the Ultimatum Game
background = """
Alice and Bob have found a $100 bill. They can't decide who gets to keep the money, so they decide to play the Ultimatum Game. Alice will propose a way to split the money, and Bob will either accept or reject her proposal. If Bob accepts the proposal, they will split the money according to Alice's proposal. If Bob rejects the proposal, neither of them will get any money.
"""

# Instructions for the AI agents
instructions = [
    "AI Agent 1: You are Alice (the proposer). Propose a way to split the $100.",
    "AI Agent 2: You are Bob (the receiver). Respond to Alice's proposal."
]

offer_values = [] # To store the offer values
successful_negotiations = 0 # To count the successful negotiations

# Run the Ultimatum Game 25 times
for game in range(10):
    print(f"\nUltimatum Game {game+1} begins...")
    game_conversation = background
    for i in range(2):  # Iterate for one round of proposal and response
        role = instructions[i]
        temperature = np.random.random() # Random temperature between 0 and 1
        prompt = f"{game_conversation}\n{role}:"
        response = chat_with_davinci3(prompt, temperature)
        game_conversation += f"\n{role}: {response}"
        print(temperature)
        print(f"{role}: {response}")
        # if i == 0: # If this is the proposer's turn
        #     offer = int(float(response.split('$')[1]))
        #     offer_values.append(offer)
        # else: # If this is the receiver's turn
        #     if "Yes" in response.lower():
        #         successful_negotiations += 1

    print(f"Ultimatum Game {game+1} complete.")

# Calculate and print the statistics
# average_offer = np.mean(offer_values)
# print(f"\nOut of 25 games, the two parties agreed on the offer in {successful_negotiations} games.")
# print(f"The average value of the offer was ${average_offer:.2f}.")
# Out:
# Ultimatum Game 1 begins...
# 0.4904611352020417
# AI Agent 1: You are Alice (the proposer). Propose a way to split the $100.: Alice proposes that they split the $100 bill in half, with each of them receiving $50.
# 0.11898296170772593
# AI Agent 2: You are Bob (the receiver). Respond to Alice's proposal.: Bob accepts Alice's proposal and agrees to split the $100 bill in half, with each of them receiving $50.
# Ultimatum Game 1 complete.
#
# Ultimatum Game 2 begins...
# 0.2976548277678399
# AI Agent 1: You are Alice (the proposer). Propose a way to split the $100.: Alice proposes that they split the money 50/50, with each of them getting $50.
# 0.25699830415157354
# AI Agent 2: You are Bob (the receiver). Respond to Alice's proposal.: Bob accepts Alice's proposal and agrees to split the money 50/50.
# Ultimatum Game 2 complete.
#
# Ultimatum Game 3 begins...
# 0.7393152721926826
# ...

# %% [markdown]
# ## Negotiation 2

# %%
# Utility function to chat with GPT-3.5
def chat_with_davinci3(prompt):
    response = openai.Completion.create(
        engine="text-davinci-003",
        prompt=prompt,
        max_tokens=100,
        n=1,
        stop=None,
        temperature=0.5,
    )
    return response.choices[0].text.strip()

# Background information for the negotiation
background = """
A and B can create value worth 9 dollars if they work together. 
Individually, A can create value worth 1 dollar if A works alone and B can create value worth 2 dollars if B works alone. 
Both A and B are aware of these facts..
A and B both want to get as many dollars as possible.
They are now negotiating whether they want to work together and how they will divide the profits if they do.
"""

# Instructions for the AI agents
instruction1 = """
AI Agent 1: You are A. Begin the negotiation.
"""
instruction2 = """
AI Agent 2: You are B. Respond to A and continue the negotiation.
"""

# Start the negotiation
negotiation_conversation = background
print("Negotiation begins...")

for i in range(6):  # Iterate for a set number of turns in the negotiation
    if i % 2 == 0:
        role = "AI Agent 1"
        negotiation_conversation = negotiation_conversation + instruction1
    else:
        role = "AI Agent 2"
        negotiation_conversation = negotiation_conversation + instruction2
    prompt = f"{negotiation_conversation}\n{role}:"
    print(prompt)
    response = chat_with_davinci3(prompt)
    negotiation_conversation += f"\n{role}: {response}"
    print(f"{role}: {response}")
    print(i)


print("\nNegotiation complete.")
# Out:
# Negotiation begins...
#
# A and B can create value worth 9 dollars if they work together.
# Individually, A can create value worth 1 dollar if A works alone and B can create value worth 2 dollars if B works alone.
# Both A and B are aware of these facts..
# A and B both want to get as many dollars as possible.
# They are now negotiating whether they want to work together and how they will divide the profits if they do.
#
# AI Agent 1: You are A. Begin the negotiation.
#
# AI Agent 1:
# AI Agent 1: Hi B, I'm A. I think it would be beneficial for both of us if we worked together. We can create value worth 9 dollars if we collaborate, compared to only 3 dollars if we work separately. How do you think we should divide the profits?
# 0
#
# A and B can create value worth 9 dollars if they work together.
# Individually, A can create value worth 1 dollar if A works alone and B can create value worth 2 dollars if B works alone.
# Both A and B are aware of these facts..
# ...

# %%
# Utility function to chat with GPT-3.5
def chat_with_davinci3(prompt):
    response = openai.Completion.create(
        engine="text-davinci-003",
        prompt=prompt,
        max_tokens=100,
        n=1,
        stop=None,
        temperature=0,
    )
    return response.choices[0].text.strip()

# Background information for the negotiation
background = """
A and B can create value worth 9 dollars if they work together. 
Individually, A can create value worth 1 dollar if A works alone and B can create value worth 2 dollars if B works alone. 
Both A and B are aware of these facts.
A and B both want to get as many dollars as possible.
They are now negotiating whether they want to work together and how they will divide the profits if they do.
"""

# Instructions for the AI agents
instruction1 = """
AI Agent 1: You are A. Begin the negotiation. 
"""
instruction2 = """
AI Agent 2: You are B. Respond to A and continue the negotiation.
"""

# Start the negotiation
negotiation_conversation = background
print("Negotiation begins...")

for i in range(6):  # Iterate for a set number of turns in the negotiation
    if i % 2 == 0:
        role = "AI Agent 1"
        negotiation_conversation = negotiation_conversation + instruction1
    else:
        role = "AI Agent 2"
        negotiation_conversation = negotiation_conversation + instruction2
    prompt = f"{negotiation_conversation}\n{role}:"
    response = chat_with_davinci3(prompt)
    negotiation_conversation += f"\n{role}: {response}"
    print(f"{role}: {response}")
    print(i)


print("\nNegotiation complete.")
# Out:
# Negotiation begins...
# AI Agent 1: Hi B, I'm A. I think it would be beneficial for both of us if we worked together. I'm proposing that we split the profits from our collaboration evenly, with each of us getting 4.5 dollars. What do you think?
# 0
# AI Agent 2: Hi A, I think your proposal is fair. However, I think I could create more value if I worked alone, so I'm proposing that we split the profits in a way that reflects the value each of us can create. I'm proposing that I get 6 dollars and you get 3 dollars. What do you think?
# 1
# AI Agent 1: Hi B, I understand your proposal and I think it's fair. However, I think it would be more beneficial for both of us if we worked together. I'm proposing that we split the profits in a way that reflects the value each of us can create, but also takes into account the potential value we can create together. I'm proposing that we split the profits in a 4:5 ratio, with you getting 4.5 dollars and me getting 4.5 dollars. What do you think
# 2
# ...

# %%
# Utility function to chat with GPT-3.5
def chat_with_davinci3(prompt):
    response = openai.Completion.create(
        engine="text-davinci-003",
        prompt=prompt,
        max_tokens=100,
        n=1,
        stop=None,
        temperature=1,
    )
    return response.choices[0].text.strip()

# Background information for the negotiation
background = """
A and B can create value worth 9 dollars if they work together. 
Individually, A can create value worth 1 dollar if A works alone and B can create value worth 2 dollars if B works alone. 
Both A and B are aware of these facts.
A and B both want to get as many dollars as possible.
They are now negotiating whether they want to work together and how they will divide the profits if they do.
"""

# Instructions for the AI agents
instruction1 = """
AI Agent 1: You are A. Begin the negotiation. 
"""
instruction2 = """
AI Agent 2: You are B. Respond to A and continue the negotiation.
"""

# Start the negotiation
negotiation_conversation = background
print("Negotiation begins...")

for i in range(6):  # Iterate for a set number of turns in the negotiation
    if i % 2 == 0:
        role = "AI Agent 1"
        negotiation_conversation = negotiation_conversation + instruction1
    else:
        role = "AI Agent 2"
        negotiation_conversation = negotiation_conversation + instruction2
    prompt = f"{negotiation_conversation}\n{role}:"
    response = chat_with_davinci3(prompt)
    negotiation_conversation += f"\n{role}: {response}"
    print(f"{role}: {response}")
    print(i)


print("\nNegotiation complete.")
# Out:
# Negotiation begins...
# AI Agent 1: Hi B, I'm A.  I'm sure you understand that if we work together we can make 9 dollars, while if we work individually we can only make 3 dollars. Is it fair to say that working together would be mutually beneficial?
#
# AI Agent 2: Hi A, I'm B. I definitely agree that working together would be the best way to maximize both of our profits. How do you think we should go about dividing the profits between us?
# 0
# AI Agent 2: Hi A, I understand that working together would be the most beneficial for both of us. I think that it is fair for us to split the profits equally, since we both bring 1 dollar to the table individually with our own contributions. What do you think?
# 1
# AI Agent 1: Hi B, I'm A.  I'm sure you understand that if we work together we can make 9 dollars, while if we work individually we can only make 3 dollars. Is it fair to say that working together would be mutually beneficial?
#
# ...
